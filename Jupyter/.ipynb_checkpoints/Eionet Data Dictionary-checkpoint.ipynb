# %% [markdown]
# Get all Bathing Waters with P9618 in this project from Wikidata and checks if they exist on eionet as a WaterBody
#
# https://dd.eionet.europa.eu/vocabularyconcept/wise/WaterBody
#
# * The project: [github salgo60/Svenskabadplatser](https://github.com/salgo60/Svenskabadplatser)
#   * European bathwaters [GITHUB](https://github.com/salgo60/EuropeanBathingWater/blob/main/README.md) / [Wikidata](https://www.wikidata.org/wiki/Wikidata:WikiProject_European_Bath_Waters)
# * this [Notebook](https://github.com/salgo60/Svenskabadplatser/blob/main/Jupyter/Eionet%20Data%20Dictionary.ipynb)
#
# **This Notebook is moved to** [github salgo60/EuropeanBathingWater](https://github.com/salgo60/Svenskabadplatser/blob/main/Jupyter/Eionet%20Data%20Dictionary.ipynb)
#
#
# Status:
#
#
#
# | Date | Total | Ok | Error
# | ------------- |:-------------:|:-------------:|:-------------:|
# | 20210610 | 3176 | 936 | 2240 |

# %%
from datetime import datetime
start_time  = datetime.now()
print("Last run: ", start_time)
# Out:
# Last run:  2021-06-12 08:49:54.218008

# %%
import pandas as pd

# %%
#
# pip install sparqlwrapper
# https://rdflib.github.io/sparqlwrapper/

import sys,json
from SPARQLWrapper import SPARQLWrapper, JSON

endpoint_url = "https://query.wikidata.org/sparql"
 
# https://w.wiki/3Tk$    
queryBath = """SELECT  (REPLACE(STR(?nodebath), ".*Q", "Q") AS ?wikidata) ?nodebath (SUBSTR(lcase(?bath),1,2) AS ?country)
(URI(CONCAT("https://dd.eionet.europa.eu/vocabularyconcept/wise/WFDProtectedArea/euProtectedAreaCode.",
       str(?bath))) AS ?eionet)  (str(?bath) AS ?bathwateridentifier){
      # ?nodebath wdt:P9616 ?bath} 
"""


def get_sparql_dataframe(endpoint_url, query):
    """
    Helper function to convert SPARQL results into a Pandas data frame.
    """
    user_agent = "salgo60/%s.%s" % (sys.version_info[0], sys.version_info[1])
 
    sparql = SPARQLWrapper(endpoint_url, agent=user_agent)
    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)
    result = sparql.query()

    processed_results = json.load(result.response)
    cols = processed_results['head']['vars']

    out = []
    for row in processed_results['results']['bindings']:
        item = []
        for c in cols:
            item.append(row.get(c, {}).get('value'))
        out.append(item)

    return pd.DataFrame(out, columns=cols)

WDBath = get_sparql_dataframe(endpoint_url, queryBath)
WDBath.shape
# Out:
# (3175, 5)

# %%
WDBath.head()
# Out:
#      wikidata                                   nodebath country  \
# 0  Q106708785  http://www.wikidata.org/entity/Q106708785      se
# 1  Q106708786  http://www.wikidata.org/entity/Q106708786      se
# 2  Q106708787  http://www.wikidata.org/entity/Q106708787      se
# 3  Q106708789  http://www.wikidata.org/entity/Q106708789      se
# 4  Q106708783  http://www.wikidata.org/entity/Q106708783      se
#
#                                               eionet bathwateridentifier
# 0  https://dd.eionet.europa.eu/vocabularyconcept/...  SE0230512000001917
# 1  https://dd.eionet.europa.eu/vocabularyconcept/...  SE0230512000001918
# 2  https://dd.eionet.europa.eu/vocabularyconcept/...  SE0230512000001919
# 3  https://dd.eionet.europa.eu/vocabularyconcept/...  SE0A21493000001925
# 4  https://dd.eionet.europa.eu/vocabularyconcept/...  SE0230512000001915

# %%
import urllib3, json
from tqdm import tqdm
http = urllib3.PoolManager()
urlHav = "https://badplatsen.havochvatten.se/badplatsen/api/detail/" 

listBath = []
for WD, row in tqdm(WDBath.iterrows(), total=WDBath.shape[0]):
    url = row["eionet"] 
    
    new_item = dict()
    new_item['wikidata'] = row["wikidata"] 
    #print(url)
    try:
        r = http.request('GET', url) 
        new_item['status'] = r.status
        if  r.status == 404 and row['country'] == "se":
            #Check if Sweden. and check API for reason
            try:
                urlHavBath = urlHav + row["bathwateridentifier"]
                rHav = http.request('GET',urlHavBath , 
                                    headers={'Content-Type': 'application/json'})
                rHavData = json.loads(rHav.data.decode('utf-8'))  
                #for key, value in rHavData.items() :
                #    print ("\t\t",key, value)
                new_item['euType'] = rHavData["euType"]
                new_item['euMotive'] = rHavData["euMotive"]
                new_item['NotEuMotive'] = rHavData["NotEuMotive"]
                
            except Exception as e:
                print ("Hav except ", e, urlHavBath, " WD:",row["wikidata"] )

    except:
        #print (r.status, url)
        new_item['status'] = r.status
    new_item['eionet'] = url 
    new_item['bathwateridentifier'] = row["bathwateridentifier"] 
    new_item['country'] = row["country"] 
    
    listBath.append(new_item)
print (len(listBath))
# Out:
#  38%|███▊      | 1191/3175 [01:08<02:23, 13.79it/s]
# Hav except  Expecting value: line 1 column 1 (char 0) https://badplatsen.havochvatten.se/badplatsen/api/detail/SE0920780000001554  WD: Q106708515
#  38%|███▊      | 1197/3175 [01:09<02:29, 13.23it/s]
# Hav except  Expecting value: line 1 column 1 (char 0) https://badplatsen.havochvatten.se/badplatsen/api/detail/SE0920780000001564  WD: Q106708524
#  43%|████▎     | 1373/3175 [01:16<01:58, 15.21it/s]
# Hav except  Expecting value: line 1 column 1 (char 0) https://badplatsen.havochvatten.se/badplatsen/api/detail/SE0110126000005596  WD: Q106673424
#  62%|██████▏   | 1957/3175 [01:50<01:27, 13.84it/s]
# Hav except  Expecting value: line 1 column 1 (char 0) https://badplatsen.havochvatten.se/badplatsen/api/detail/SE0A21439000001358  WD: Q106708374
# Hav except  Expecting value: line 1 column 1 (char 0) https://badplatsen.havochvatten.se/badplatsen/api/detail/SE0A21439000001360  WD: Q106708376
# 100%|██████████| 3175/3175 [02:59<00:00, 17.66it/s]
# 3175

# %%
#listBath

# %%
Eionettot = pd.DataFrame(listBath,
                  columns=['wikidata','country','bathwateridentifier','status','eionet','euType','euMotive','NotEuMotive'])
Eionettot.shape
# Out:
# (3175, 8)

# %%
Eionettot.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3175 entries, 0 to 3174
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   wikidata             3175 non-null   object
#  1   country              3175 non-null   object
#  2   bathwateridentifier  3175 non-null   object
#  3   status               3175 non-null   int64
#  4   eionet               3175 non-null   object
#  5   euType               2202 non-null   object
#  6   euMotive             17 non-null     object
#  7   NotEuMotive          0 non-null      float64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 198.6+ KB

# %%
pd.set_option('max_colwidth', 400)
Eionettot.head(10)
# Out:
#      wikidata country bathwateridentifier  status  \
# 0  Q106708785      se  SE0230512000001917     404
# 1  Q106708786      se  SE0230512000001918     404
# 2  Q106708787      se  SE0230512000001919     404
# 3  Q106708789      se  SE0A21493000001925     404
# 4  Q106708783      se  SE0230512000001915     404
# 5  Q106708788      se  SE0230512000001920     404
# 6  Q106708790      se  SE0930821000001933     404
# 7  Q106708784      se  SE0230512000001916     404
# 8  Q106708793      se  SE0930821000001936     404
# 9  Q106708791      se  SE0930821000001934     404
#
#                                                                                                        eionet  \
# 0  https://dd.eionet.europa.eu/vocabularyconcept/wise/WFDProtectedArea/euProtectedAreaCode.SE0230512000001917
# 1  https://dd.eionet.europa.eu/vocabularyconcept/wise/WFDProtectedArea/euProtectedAreaCode.SE0230512000001918
# 2  https://dd.eionet.europa.eu/vocabularyconcept/wise/WFDProtectedArea/euProtectedAreaCode.SE0230512000001919
# 3  https://dd.eionet.europa.eu/vocabularyconcept/wise/WFDProtectedArea/euProtectedAreaCode.SE0A21493000001925
# 4  https://dd.eionet.europa.eu/vocabularyconcept/wise/WFDProtectedArea/euProtectedAreaCode.SE0230512000001915
# 5  https://dd.eionet.europa.eu/vocabularyconcept/wise/WFDProtectedArea/euProtectedAreaCode.SE0230512000001920
# 6  https://dd.eionet.europa.eu/vocabularyconcept/wise/WFDProtectedArea/euProtectedAreaCode.SE0930821000001933
# 7  https://dd.eionet.europa.eu/vocabularyconcept/wise/WFDProtectedArea/euProtectedAreaCode.SE0230512000001916
# 8  https://dd.eionet.europa.eu/vocabularyconcept/wise/WFDProtectedArea/euProtectedAreaCode.SE0930821000001936
# 9  https://dd.eionet.europa.eu/vocabularyconcept/wise/WFDProtectedArea/euProtectedAreaCode.SE0930821000001934
#
#   euType euMotive  NotEuMotive
# 0  False     None          NaN
# 1  False     None          NaN
# 2  False     None          NaN
# 3  False     None          NaN
# 4  False     None          NaN
# 5  False     None          NaN
# 6  False     None          NaN
# 7  False     None          NaN
# 8  False     None          NaN
# 9  False     None          NaN

# %%
#Eionettot["link"] = "<a href='https://dd.eionet.europa.eu/vocabularyconcept/wise/WFDProtectedArea/euProtectedAreaCode." + Eionettot["eionet"].astype(str) + "'">link eionet</a>"
Eionettot["link"] = "<a href='" + Eionettot["eionet"].astype(str) + "'>link eionet</a>"
Eionettot["WD"] = "<a href='https://www.wikidata.org/wiki/" + Eionettot["wikidata"].astype(str) + "'>link WD</a>"

# %%
from IPython.display import display, HTML  

#Eionettot.value_counts({"status","country"})
#Eionettot[['status', 'country']].apply(pd.Series.value_counts)
HTML(Eionettot[{'WD','country','bathwateridentifier','status','link','euType','euMotive','NotEuMotive'}].tail(50).to_html(escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>status</th>
#       <th>WD</th>
#       <th>country</th>
#       <th>bathwateridentifier</th>
#       <th>link</th>
#       <th>euType</th>
#       <th>NotEuMotive</th>
#       <th>euMotive</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>3125</th>
#       <td>404</td>
#       <td><a href='https://www.wikidata.org/wiki/Q106710492'>link WD</a></td>
#       <td>se</td>
#       <td>SE0241863000003431</td>
#       <td><a href='https://dd.eionet.europa.eu/vocabularyconcept/wise/WFDProtectedArea/euProtectedAreaCode.SE0241863000003431'>link eionet</a></td>
#       <td>False</td>
#       <td>NaN</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>3126</th>
#       <td>404</td>
#       <td><a href='https://www.wikidata.org/wiki/Q106710493'>link WD</a></td>
#       <td>se</td>
#       <td>SE0241863000003434</td>
#       <td><a href='https://dd.eionet.europa.eu/vocabularyconcept/wise/WFDProtectedArea/euProtectedAreaCode.SE0241863000003434'>link eionet</a></td>
#       <td>False</td>
#       <td>NaN</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>3127</th>
#       <td>404</td>
#       <td><a href='https://www.wikidata.org/wiki/Q106710497'>link WD</a></td>
#       <td>se</td>
#       <td>SE0712282000003437</td>
#       <td><a href='https://dd.eionet.europa.eu/vocabularyconcept/wise/WFDProtectedArea/euProtectedAreaCode.SE0712282000003437'>link eionet</a></td>
#       <td>False</td>
#       <td>NaN</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>3128</th>
#       <td>404</td>
#       <td><a href='https://www.wikidata.org/wiki/Q106710481'>link WD</a></td>
#       <td>se</td>
#       <td>SE0812418000003416</td>
#       <td><a href='https://dd.eionet.europa.eu/vocabularyconcept/wise/WFDProtectedArea/euProtectedAreaCode.SE0812418000003416'>link eionet</a></td>
#       <td>False</td>
#       <td>NaN</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>3129</th>
#       <td>404</td>
#       <td><a href='https://www.wikidata.org/wiki/Q106710504'>link WD</a></td>
#       <td>se</td>
#       <td>SE0712282000003442</td>
#       <td><a href='https://dd.eionet.europa.eu/vocabularyconcept/wise/WFDProtectedArea/euProtectedAreaCode.SE0712282000003442'>link eionet</a></td>
#       <td>False</td>
#       <td>NaN</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>3130</th>
#       <td>404</td>
#       <td><a href='https://www.wikidata.org/wiki/Q106710506'>link WD</a></td>
#       <td>se</td>
#       <td>SE0712282000003444</td>
#       <td><a href='https://dd.eionet.europa.eu/vocabularyconcept/wise/WFDProtectedArea/euProtectedAreaCode.SE0712282000003444'>link eionet</a></td>
#       <td>False</td>
#       <td>NaN</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>3131</th>
#       <td>404</td>
#       <td><a href='https://www.wikidata.org/wiki/Q106710507'>link WD</a></td>
#       <td>se</td>
#       <td>SE0712282000003447</td>
#       <td><a href='https://dd.eionet.europa.eu/vocabularyconcept/wise/WFDProtectedArea/euProtectedAreaCode.SE0712282000003447'>link eionet</a></td>
#       <td>False</td>
#       <td>NaN</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>3132</th>
#       <td>404</td>
#       <td><a href='https://www.wikidata.org/wiki/Q106710494'>link WD</a></td>
#       <td>se</td>
#       <td>SE0712282000003435</td>
#       <td><a href='https://dd.eionet.europa.eu/vocabularyconcept/wise/WFDProtectedArea/euProtectedAreaCode.SE0712282000003435'>link eionet</a></td>
#       <td>False</td>
#       <td>NaN</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>3133</th>
#       <td>200</td>
#       <td><a href='https://www.wikidata.org/wiki/Q106710500'>link WD</a></td>
#       <td>se</td>
#       <td>SE0712282000003439</td>
#       <td><a href='https://dd.eionet.europa.eu/vocabularyconcept/wise/WFDProtectedArea/euProtectedAreaCode.SE0712282000003439'>link eionet</a></td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>3134</th>
#       <td>404</td>
#       <td><a href='https://www.wikidata.org/wiki/Q106710502'>link WD</a></td>
#       <td>se</td>
#       <td>SE0712282000003441</td>
#       <td><a href='https://dd.eionet.europa.eu/vocabularyconcept/wise/WFDProtectedArea/euProtectedAreaCode.SE0712282000003441'>link eionet</a></td>
#       <td>False</td>
#       <td>NaN</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>3135</th>
#       <td>404</td>
#       <td><a href='https://www.wikidata.org/wiki/Q106710668'>link WD</a></td>
#       <td>se</td>
#       <td>SE0712281000003450</td>
#       <td><a href='https://dd.eionet.europa.eu/vocabularyconcept/wise/WFDProtectedArea/euProtectedAreaCode.SE0712281000003450'>link eionet</a></td>
#       <td>False</td>
#       <td>NaN</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>3136</th>
#       <td>404</td>
#       <td><a href='https://www.wikidata.org/wiki/Q106710672'>link WD</a></td>
#       <td>se</td>
#       <td>SE0712281000003453</td>
#       <td><a href='https://dd.eionet.europa.eu/vocabularyconcept/wise/WFDProtectedArea/euProtectedAreaCode.SE0712281000003453'>link eionet</a></td>
#       <td>False</td>
#       <td>NaN</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>3137</th>
#       <td>404</td>
#       <td><a href='https://www.wikidata.org/wiki/Q106710670'>link WD</a></td>
#       <td>se</td>
#       <td>SE0712281000003452</td>
#       <td><a href='https://dd.eionet.europa.eu/vocabularyconcept/wise/WFDProtectedArea/euProtectedAreaCode.SE0712281000003452'>link eionet</a></td>
#       <td>False</td>
#       <td>NaN</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>3138</th>
#       <td>404</td>
#       <td><a href='https://www.wikidata.org/wiki/Q106710673'>link WD</a></td>
#       <td>se</td>
#       <td>SE0712281000003454</td>
#       <td><a href='https://dd.eionet.europa.eu/vocabularyconcept/wise/WFDProtectedArea/euProtectedAreaCode.SE0712281000003454'>link eionet</a></td>
#       <td>False</td>
#       <td>NaN</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>3139</th>
#       <td>404</td>
#       <td><a href='https://www.wikidata.org/wiki/Q106947945'>link WD</a></td>
#       <td>se</td>
#       <td>SE0712281000003454</td>
#       <td><a href='https://dd.eionet.europa.eu/vocabularyconcept/wise/WFDProtectedArea/euProtectedAreaCode.SE0712281000003454'>link eionet</a></td>
#       <td>False</td>
#       <td>NaN</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>3140</th>
#       <td>404</td>
#       <td><a href='https://www.wikidata.org/wiki/Q106710675'>link WD</a></td>
#       <td>se</td>
#       <td>SE0712281000003455</td>
#       <td><a href='https://dd.eionet.europa.eu/vocabularyconcept/wise/WFDProtectedArea/euProtectedAreaCode.SE0712281000003455'>link eionet</a></td>
#       <td>False</td>
#       <td>NaN</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>3141</th>
#       <td>404</td>
#       <td><a href='https://www.wikidata.org/wiki/Q106710677'>link WD</a></td>
#       <td>se</td>
#       <td>SE0712281000003456</td>
#       <td><a href='https://dd.eionet.europa.eu/vocabularyconcept/wise/WFDProtectedArea/euProtectedAreaCode.SE0712281000003456'>link eionet</a></td>
#       <td>False</td>
#       <td>NaN</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>3142</th>
#       <td>404</td>
#       <td><a href='https://www.wikidata.org/wiki/Q106710666'>link WD</a></td>
#       <td>se</td>
#       <td>SE0712282000003448</td>
#       <td><a href='https://dd.eionet.europa.eu/vocabularyconcept/wise/WFDProtectedArea/euProtectedAreaCode.SE0712282000003448'>link eionet</a></td>
#       <td>False</td>
#       <td>NaN</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>3143</th>
#       <td>404</td>
#       <td><a href='https://www.wikidata.org/wiki/Q106710681'>link WD</a></td>
#       <td>se</td>
#       <td>SE0712281000003460</td>
#       <td><a href='https://dd.eionet.europa.eu/vocabularyconcept/wise/WFDProtectedArea/euProtectedAreaCode.SE0712281000003460'>link eionet</a></td>
#       <td>False</td>
#       <td>NaN</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>3144</th>
#       <td>404</td>
#       <td><a href='https://www.wikidata.org/wiki/Q106710678'>link WD</a></td>
#       <td>se</td>
#       <td>SE07

# %%
EionettotOk = Eionettot[(Eionettot['status']==200)] 
EionettotError = Eionettot[(Eionettot['status']==404)]

# %%
EionettotOk.shape
# Out:
# (936, 10)

# %%
EionettotError.shape
# Out:
# (2239, 10)

# %%
EionettotError.value_counts("country")
# Out:
# country
# se    2207
# es      13
# gr      12
# hr       4
# de       1
# ie       1
# uk       1
# dtype: int64

# %%
EionettotError.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2239 entries, 0 to 3173
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   wikidata             2239 non-null   object
#  1   country              2239 non-null   object
#  2   bathwateridentifier  2239 non-null   object
#  3   status               2239 non-null   int64
#  4   eionet               2239 non-null   object
#  5   euType               2202 non-null   object
#  6   euMotive             17 non-null     object
#  7   NotEuMotive          0 non-null      float64
#  8   link                 2239 non-null   object
#  9   WD                   2239 non-null   object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 192.4+ KB

# %%
HTML(EionettotError[{'WD','country','bathwateridentifier','status','link','euType','euMotive','NotEuMotive'}].tail(10).to_html(escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>status</th>
#       <th>WD</th>
#       <th>country</th>
#       <th>bathwateridentifier</th>
#       <th>link</th>
#       <th>euType</th>
#       <th>NotEuMotive</th>
#       <th>euMotive</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>3161</th>
#       <td>404</td>
#       <td><a href='https://www.wikidata.org/wiki/Q106710724'>link WD</a></td>
#       <td>se</td>
#       <td>SE0712281000003480</td>
#       <td><a href='https://dd.eionet.europa.eu/vocabularyconcept/wise/WFDProtectedArea/euProtectedAreaCode.SE0712281000003480'>link eionet</a></td>
#       <td>False</td>
#       <td>NaN</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>3165</th>
#       <td>404</td>
#       <td><a href='https://www.wikidata.org/wiki/Q106710731'>link WD</a></td>
#       <td>se</td>
#       <td>SE0910680000003486</td>
#       <td><a href='https://dd.eionet.europa.eu/vocabularyconcept/wise/WFDProtectedArea/euProtectedAreaCode.SE0910680000003486'>link eionet</a></td>
#       <td>False</td>
#       <td>NaN</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>3166</th>
#       <td>404</td>
#       <td><a href='https://www.wikidata.org/wiki/Q106710745'>link WD</a></td>
#       <td>se</td>
#       <td>SE0910680000003490</td>
#       <td><a href='https://dd.eionet.europa.eu/vocabularyconcept/wise/WFDProtectedArea/euProtectedAreaCode.SE0910680000003490'>link eionet</a></td>
#       <td>False</td>
#       <td>NaN</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>3167</th>
#       <td>404</td>
#       <td><a href='https://www.wikidata.org/wiki/Q106710747'>link WD</a></td>
#       <td>se</td>
#       <td>SE0910680000003491</td>
#       <td><a href='https://dd.eionet.europa.eu/vocabularyconcept/wise/WFDProtectedArea/euProtectedAreaCode.SE0910680000003491'>link eionet</a></td>
#       <td>False</td>
#       <td>NaN</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>3168</th>
#       <td>404</td>
#       <td><a href='https://www.wikidata.org/wiki/Q106710750'>link WD</a></td>
#       <td>se</td>
#       <td>SE0910680000003496</td>
#       <td><a href='https://dd.eionet.europa.eu/vocabularyconcept/wise/WFDProtectedArea/euProtectedAreaCode.SE0910680000003496'>link eionet</a></td>
#       <td>False</td>
#       <td>NaN</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>3169</th>
#       <td>404</td>
#       <td><a href='https://www.wikidata.org/wiki/Q106710748'>link WD</a></td>
#       <td>se</td>
#       <td>SE0910680000003492</td>
#       <td><a href='https://dd.eionet.europa.eu/vocabularyconcept/wise/WFDProtectedArea/euProtectedAreaCode.SE0910680000003492'>link eionet</a></td>
#       <td>False</td>
#       <td>NaN</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>3170</th>
#       <td>404</td>
#       <td><a href='https://www.wikidata.org/wiki/Q106710755'>link WD</a></td>
#       <td>se</td>
#       <td>SE0910680000003500</td>
#       <td><a href='https://dd.eionet.europa.eu/vocabularyconcept/wise/WFDProtectedArea/euProtectedAreaCode.SE0910680000003500'>link eionet</a></td>
#       <td>False</td>
#       <td>NaN</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>3171</th>
#       <td>404</td>
#       <td><a href='https://www.wikidata.org/wiki/Q106710753'>link WD</a></td>
#       <td>se</td>
#       <td>SE0910680000003498</td>
#       <td><a href='https://dd.eionet.europa.eu/vocabularyconcept/wise/WFDProtectedArea/euProtectedAreaCode.SE0910680000003498'>link eionet</a></td>
#       <td>False</td>
#       <td>NaN</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>3172</th>
#       <td>404</td>
#       <td><a href='https://www.wikidata.org/wiki/Q106710758'>link WD</a></td>
#       <td>se</td>
#       <td>SE0910680000003504</td>
#       <td><a href='https://dd.eionet.europa.eu/vocabularyconcept/wise/WFDProtectedArea/euProtectedAreaCode.SE0910680000003504'>link eionet</a></td>
#       <td>False</td>
#       <td>NaN</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>3173</th>
#       <td>404</td>
#       <td><a href='https://www.wikidata.org/wiki/Q106710756'>link WD</a></td>
#       <td>se</td>
#       <td>SE0910680000003501</td>
#       <td><a href='https://dd.eionet.europa.eu/vocabularyconcept/wise/WFDProtectedArea/euProtectedAreaCode.SE0910680000003501'>link eionet</a></td>
#       <td>False</td>
#       <td>NaN</td>
#       <td>None</td>
#     </tr>
#   </tbody>
# </table>

# %%
EionettotErrorEuType = EionettotError[EionettotError["euType"] == True] 
HTML(EionettotErrorEuType[{'WD','country','bathwateridentifier','status','link','euType','euMotive','NotEuMotive'}].tail(10).to_html(escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>status</th>
#       <th>WD</th>
#       <th>country</th>
#       <th>bathwateridentifier</th>
#       <th>link</th>
#       <th>euType</th>
#       <th>NotEuMotive</th>
#       <th>euMotive</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>250</th>
#       <td>404</td>
#       <td><a href='https://www.wikidata.org/wiki/Q106707865'>link WD</a></td>
#       <td>se</td>
#       <td>SE0930880000000783</td>
#       <td><a href='https://dd.eionet.europa.eu/vocabularyconcept/wise/WFDProtectedArea/euProtectedAreaCode.SE0930880000000783'>link eionet</a></td>
#       <td>True</td>
#       <td>NaN</td>
#       <td>Nyrenoverat hopptorn med flertalet badande över tid ca 250 personer per dag samt intilliggande aktivitetsområde. Här finns tillgång till basket och volleybollplaner samt utegym och flertalet grillplatser</td>
#     </tr>
#     <tr>
#       <th>252</th>
#       <td>404</td>
#       <td><a href='https://www.wikidata.org/wiki/Q106707868'>link WD</a></td>
#       <td>se</td>
#       <td>SE0930880000000786</td>
#       <td><a href='https://dd.eionet.europa.eu/vocabularyconcept/wise/WFDProtectedArea/euProtectedAreaCode.SE0930880000000786'>link eionet</a></td>
#       <td>True</td>
#       <td>NaN</td>
#       <td>Mer än 200 badande per dag. Central badplats i Kalmar med mycket turister.</td>
#     </tr>
#     <tr>
#       <th>253</th>
#       <td>404</td>
#       <td><a href='https://www.wikidata.org/wiki/Q106707874'>link WD</a></td>
#       <td>se</td>
#       <td>SE0930880000000792</td>
#       <td><a href='https://dd.eionet.europa.eu/vocabularyconcept/wise/WFDProtectedArea/euProtectedAreaCode.SE0930880000000792'>link eionet</a></td>
#       <td>True</td>
#       <td>NaN</td>
#       <td>Stora investeringar 2019 med en väl tilltagen brygga i ett populärt område i norra delarna av Kalmar. Fler än 200 badande per dag i snitt 2019.</td>
#     </tr>
#     <tr>
#       <th>585</th>
#       <td>404</td>
#       <td><a href='https://www.wikidata.org/wiki/Q106710200'>link WD</a></td>
#       <td>se</td>
#       <td>SE0241860000003270</td>
#       <td><a href='https://dd.eionet.europa.eu/vocabularyconcept/wise/WFDProtectedArea/euProtectedAreaCode.SE0241860000003270'>link eionet</a></td>
#       <td>True</td>
#       <td>NaN</td>
#       <td>Uppskattningsvis badar fler än 200 personer här vid god väderlek under badsäsongen. Camping finns i anslutning till badplatsen.</td>
#     </tr>
#     <tr>
#       <th>641</th>
#       <td>404</td>
#       <td><a href='https://www.wikidata.org/wiki/Q106707517'>link WD</a></td>
#       <td>se</td>
#       <td>SE0441293000000427</td>
#       <td><a href='https://dd.eionet.europa.eu/vocabularyconcept/wise/WFDProtectedArea/euProtectedAreaCode.SE0441293000000427'>link eionet</a></td>
#       <td>True</td>
#       <td>NaN</td>
#       <td>Badplatsen har fler än 200 besökare i genomsnitt normal sommardag.</td>
#     </tr>
#     <tr>
#       <th>916</th>
#       <td>404</td>
#       <td><a href='https://www.wikidata.org/wiki/Q106677306'>link WD</a></td>
#       <td>se</td>
#       <td>SE0441280000004499</td>
#       <td><a href='https://dd.eionet.europa.eu/vocabularyconcept/wise/WFDProtectedArea/euProtectedAreaCode.SE0441280000004499'>link eionet</a></td>
#       <td>True</td>
#       <td>NaN</td>
#       <td>Trädäcken vid badplatsen Sundspromenaden är en naturlig och mycket populär mötesplats för alla sol- och badsugna under sommarhalvåret i Malmö men används även för vinterbadare. Besöksstatistiken för Sundspromenadens badplats har registrerats under badsäsongen som ca 3000-10000personer per vecka beroende på väder.</td>
#     </tr>
#     <tr>
#       <th>999</th>
#       <td>404</td>
#       <td><a href='https://www.wikidata.org/wiki/Q106702268'>link WD</a></td>
#       <td>se</td>
#       <td>SE0411080000000220</td>
#       <td><a href='https://dd.eionet.europa.eu/vocabularyconcept/wise/WFDProtectedArea/euProtectedAreaCode.SE0411080000000220'>link eionet</a></td>
#       <td>True</td>
#       <td>NaN</td>
#       <td>En insjö med klart vatten som är en vattentäkt. Badplatsen är välbesökt året runt. Föreningen har gjort flera grillplatser, byggt en egen vacker grillkåta och byggt till lekplatsen på badplatsen. Badplatsen har ett bryggomslutet barnbad och ytterligare en brygga med hopptorn samt två flottar. Toaletter och omklädningsbås finns. Antalet besökare uppskattas till drygt 200 personer fina sommardagar.</td>
#     </tr>
#     <tr>
#       <th>2180</th>
#       <td>404</td>
#       <td><a href='https://www.wikidata.org/wiki/Q106711900'>link WD</a></td>
#       <td>se</td>
#       <td>SE0241814000004068</td>
#       <td><a href='https://dd.eionet.europa.eu/vocabularyconcept/wise/WFDProtectedArea/euProtectedAreaCode.SE0241814000004068'>link eionet</a></td>
#       <td>True</td>
#       <td>NaN</td>
#       <td>Många badande från Örebro p.g.a. närheten till E18, uppskattningsvis över 200 badande vid god väderlek.</td>
#     </tr>
#     <tr>
#       <th>2211</th>
#       <td>404</td>
#       <td><a href='https://www.wikidata.org/wiki/Q106711936'>link WD</a></td>
#       <td>se</td>
#       <td>SE0A21487000004208</td>
#       <td><a href='https://dd.eionet.europa.eu/vocabularyconcept/wise/WFDProtectedArea/euProtectedAreaCode.SE0A21487000004208'>link eionet</a></td>
#       <td>True</td>
#       <td>NaN</td>
#       <td>Vi bedömer att Skräcklan-barnbadet uppfyller kriterierna för EU-bad med över 200 badande per dag. Det är också en stadsnära badplats som är iordningsställd för bad med toalett och handikappramp. Det är även många skolklasser och fritids som är där och badar.</td>
#     </tr>
#     <tr>
#       <th>2582</th>
#       <td>404</td>
#       <td><a href='https://www.wikidata.org/wiki/Q106702255'>link WD</a></td>
#       <td>se</td>
#       <td>SE0411080000000207</td>
#       <td><a href='https://dd.eionet.europa.eu/vocabularyconcept/wise/WFDProtectedArea/euProtectedAreaCode.SE0411080000000207'>link eionet</a></td>
#       <td>True</td>
#       <td>NaN</td>
#       <td>Antalet besökare uppskattas till runt 500 personer fina sommardagar</td>
#     </tr>
#   </tbody>
# </table>

# %%
EionettotError["euMotive"].value_counts()
# Out:
# <200 badande per dag. Ej längre EU bad.                                                                                                                                                                                                                                                                                                                                                                            3
# Stora investeringar 2019 med en väl tilltagen brygga i ett populärt område i norra delarna av Kalmar. Fler än 200 badande per dag i snitt 2019.                                                                                                                                                                                                                                                                    1
# Antalet besökare uppskattas till runt 500 personer fina sommardagar                                                                                                                                                                                                                                                                                                                                                1
# Trädäcken vid badplatsen Sundspromenaden är en naturlig och mycket populär mötesplats för alla sol- och badsugna under sommarhalvåret i Malmö men används även för vinterbadare. Besöksstatistiken för Sundspromenadens badplats har registrerats under badsäsongen som ca 3000-10000personer per vecka beroende på väder.                                                                                         1
# Många badande från Örebro p.g.a. närheten till E18, uppskattningsvis över 200 badande vid god väderlek.                                                                                                                                                                                                                                                                                                            1
# Badet vid Gyllebosjön är mycket populärt och välbesökt. Badet har lösningar för tillgänglighetsanpassning.                                                                                                                                                                                                                                                                                                         1
# Badplatsen har fler än 200 besökare i genomsnitt normal sommardag.                                                                                                                                                                                                                                                                                                                                                 1
# Felaktig inmatning                                                                                                                                                                                                                                                                                                                                                                                                 1
# Badet i skydd av pirarmen i Baskemölla är mycket välbesökt av barnfamiljer.                                                                                                                                                                                                                                                                                                                                        1
# En insjö med klart vatten som är en vattentäkt. Badplatsen är välbesökt året runt. Föreningen har gjort flera grillplatser, byggt en egen vacker grillkåta och byggt till lekplatsen på badplatsen. Badplatsen har ett bryggomslutet barnbad och ytterligare en brygga med hopptorn samt två flottar. Toaletter och omklädningsbås finns. Antalet besökare uppskattas till drygt 200 personer fina sommardagar.    1
# Vi bedömer att Skräcklan-barnbadet uppfyller kriterierna för EU-bad med över 200 badande per dag. Det är också en stadsnära badplats som är iordningsställd för bad med toalett och handikappramp. Det är även många skolklasser och fritids som är där och badar.                                                                                                                                                 1
# Nyrenoverat hopptorn med flertalet badande över tid ca 250 personer per dag samt intilliggande aktivitetsområde. Här finns tillgång till basket och volleybollplaner samt utegym och flertalet grillplatser                                                                                                                                                                                                        1
# Stora investeringar senaste åren intill en camping med mycket turister. Mer än 200 badande per dag 2019.                                                                                                                                                                                                                                                                                                           1
# Mer än 200 badande per dag. Central badplats i Kalmar med mycket turister.                                                                                                                                                                                                                                                                                                                                         1
# Uppskattningsvis badar fler än 200 personer här vid god väderlek under badsäsongen. Camping finns i anslutning till badplatsen.                                                                                                                                                                                                                                                                                    1
# Name: euMotive, dtype: int64

# %%
EionettotOk.shape
# Out:
# (936, 10)

# %%
EionettotOk.value_counts("country")
# Out:
# country
# se    487
# dk     36
# de     35
# pt     33
# fr     27
# ie     24
# it     23
# lt     22
# fi     21
# uk     21
# es     21
# nl     20
# pl     20
# hu     17
# ee     17
# si     16
# bg     14
# ro     11
# hr     10
# at      9
# lv      9
# sk      8
# al      8
# lu      8
# be      7
# cz      6
# mt      6
# dtype: int64

# %%
EionettotOk.to_csv("BathIdentifier_Ok.csv")
EionettotError.to_csv("BathIdentifier_Error.csv")
Eionettot.to_csv("BathIdentifier_All.csv")

# %% [markdown]
# Generate Markdown table eg.
# | 20210610 | 3176 | 2240 | 936 |

# %%
print("|",start_time.strftime("%Y%m%d"),"|", \
      Eionettot.shape[0],"|", \
      EionettotOk.shape[0],"|", \
      EionettotError.shape[0],"|",)
# Out:
# | 20210612 | 3175 | 936 | 2239 |

# %%
end = datetime.now()
print("Ended: ", end) 
print('Time elapsed (hh:mm:ss.ms) {}'.format(datetime.now() - start_time))
# Out:
# Ended:  2021-06-12 08:52:56.770512
# Time elapsed (hh:mm:ss.ms) 0:03:02.552656
